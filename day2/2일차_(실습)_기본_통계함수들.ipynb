# %% [markdown]
# ## 기본 통계 함수들
# #### 5명의 학생들에 대한 성적을 입력받아 데이터를 생성하시오.
# #### 생성한 성적에 대하여 아래의 통계, 수학 계산을 수행하시오.
# #### 합, 평균, 분산, 표준편차

# %%
# numpy를 활용하지 않은 경우

scores = [ ]
for i in range(5):
    val = int(input("%d번 성적 입력 -> " %(i+1)))
    scores.append(val)


print('\n입력된 전체점수')
print(scores, '\n')

# 합계, 평균 구하기
sumR = sum(scores)
aveR = sumR / len(scores)

print('합계 : %10d' % sumR)
print('평균 : %10.2f' % aveR)
# Out:
# 1번 성적 입력 -> 1
# 2번 성적 입력 -> 2
# 3번 성적 입력 -> 3
# 4번 성적 입력 -> 4
# 5번 성적 입력 -> 5
#
# 입력된 전체점수
# [1, 2, 3, 4, 5]
#
# 합계 :         15
# 평균 :       3.00

# %%
# 합계, 평균 구하기
sumR =
aveR =

print('합계 : %10d' % sumR)
print('평균 : %10.2f' % aveR)

# %%
# 분산, 표준편차 구하기
r = 0
for i in range(5):
  r += (scores[i] - aveR) ** 2

varR = r / len(scores)
stdR = varR ** (1/2)

print('합계 : %10d' % sumR)
print('평균 : %10.2f' % aveR)
print('분산 : %10.2f' % varR)
print('표준편차 : %10.2f' % stdR)
# Out:
# 합계 :         15
# 평균 :       3.00
# 분산 :       2.00
# 표준편차 :       1.41

# %%
# numpy 활용하는 경우
import numpy as np

scores = [ ]
for i in range(5):
    val = int(input("%d번 성적 입력 -> " %(i+1)))
    scores.append(val)

print('\n입력된 전체점수')
print(scores)

sumR = np.sum(scores)
aveR = np.mean(scores)
varR = np.var(scores)
stdR = np.std(scores)

print('합계 : %10d' % sumR)
print('평균 : %10.2f' % aveR)
print('분산 : %10.2f' % varR)
print('표준편차 : %10.2f' % stdR)
# Out:
# 1번 성적 입력 -> 1
# 2번 성적 입력 -> 2
# 3번 성적 입력 -> 3
# 4번 성적 입력 -> 4
# 5번 성적 입력 -> 5
#
# 입력된 전체점수
# [1, 2, 3, 4, 5]
# 합계 :         15
# 평균 :       3.00
# 분산 :       2.00
# 표준편차 :       1.41
